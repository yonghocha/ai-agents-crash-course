# %% [markdown]
# # Creating a Simple Agent with Tracing

# %%
import dotenv
import os

from openai import OpenAI

dotenv.load_dotenv()

if not os.environ.get("OPENAI_API_KEY"):
    print(
        """Error: OPENAI_API_KEY environment variable not set. Please copy the .env.template file as .env and fill it in.
    
    You can execute these commands in the terminal to get started:
    cp .env.template .env
    code .env
    """
    )

# Test OpenAI Access
print(
    OpenAI()
    .responses.create(
        model=os.environ["OPENAI_DEFAULT_MODEL"], input="Say: We are up and running!"
    )
    .output_text
)
# Out:
# We are up and running!

# %%
from agents import Agent, Runner, trace
from openai.types.responses import ResponseTextDeltaEvent

# %% [markdown]
# Create a simple Nutrition Assistant Agent

# %%
nutrition_agent = Agent(
    name = "Nutrition Assistant",
    instructions="""
    You are a helpful assistant giving out nutrition advice.
    You give concise answers
"""
)

# %% [markdown]
# Let's execute the Agent:

# %%
with trace("Simple Nutrition Agent"):
    result = await Runner.run(nutrition_agent, "How healthy are bananas?")

print(result)
# Out:
# RunResult:
# - Last agent: Agent(name="Nutrition Assistant", ...)
# - Final output (str):
#     Generally yes—bananas are nutritious and convenient.
#
#     Key nutrients (per medium banana, ~118 g):
#     - Potassium: ~420–450 mg
#     - Vitamin B6: ~0.4 mg
#     - Vitamin C: ~10 mg
#     - Dietary fiber: ~3 g
#     - Calories: ~105
#     - Carbs: mainly natural sugars and starch
#
#     Benefits:
#     - Supports heart and muscle function (potassium)
#     - Aids digestion (fiber)
#     - Provides quick energy and may help with satiety
#
#     Considerations:
#     - Energy/sugar content is higher than some fruits, so portion if watching sugar/calorie intake.
#     - Unripe vs ripe: greener (more resistant starch) digests slower; ripe (more sugar) is sweeter.
#
#     Overall, they fit well in a balanced diet.
# - 2 new item(s)
# - 1 raw response(s)
# - 0 input guardrail result(s)
# - 0 output guardrail result(s)
# (See `RunResult` for more details)

# %% [markdown]
# Streaming the answer to the screen, token by token

# %%
response_stream = Runner.run_streamed(nutrition_agent, "How healthy are bananas?")

async for event in response_stream.stream_events():
    if event.type == "raw_response_event" and isinstance(
        event.data, ResponseTextDeltaEvent
    ):
        print(event.data.delta, end="", flush=True)
# Out:
# Bananas are healthy as part of a balanced diet.
#
# Key benefits:
# - Good source of potassium (supports heart and muscle function)
# - vitamin B6, vitamin C, and dietary fiber
# - Low in fat and calories per medium fruit
# - Easy, portable source of quick energy
#
# Things to consider:
# - Moderate sugar content; portion if watching blood sugar (1 medium banana is typical)
# - Not a complete source of all nutrients; vary fruit/vegetables
# - Allergies are rare
#
# Tip: pair with protein (peanut butter, yogurt) for staying power.

# %% [markdown]
# _Good Job!_
